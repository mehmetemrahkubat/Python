# %% [markdown]
# # Veri Bilimi Proje Yönetimi

# %% [markdown]
#     Adım 1: İş bilgisi, problemin tanımlanması ve beklenti yönetimi
#     Adım 2: Literatür taraması ve en iyi uygulamaların araştırılması
#     Adım 3: Veriyi anlamak
#     Adım 4: Özellik mühendisliği
#     Adım 5: Veri ön işleme
#     Adım 6: Modelleme ve model başarısı değerlendirme
#     Adım 7: Çalışmanın canlı sisteme entegrasyonu

# %% [markdown]
# ## Veri Bilimi Proje Döngüsü

# %% [markdown]
# ![1_M2qsp63rH1vSac2ZqC4ZJA.png](attachment:1_M2qsp63rH1vSac2ZqC4ZJA.png)

# %% [markdown]
# ![OnPaste.20220515-192048.png](attachment:OnPaste.20220515-192048.png)

# %% [markdown]
# ![2779091-e1417258199535.png](attachment:2779091-e1417258199535.png)
